# %% [raw]
# # Atividade 1 — Disciplina Otimização
# **Universidade Federal do Amazonas — PPGEE**
# Prof. Kenny Vinente dos Santos, Dr. | kennyvinente@ufam.edu.br
# Aluno : Gabriel Nunes da Silva - Mat: 2250798

# %% [markdown]
# Import all packages

# %%
using LinearAlgebra
using Plots
using ForwardDiff

# Importar norm para usar diretamente
import LinearAlgebra: norm

# %%
using Pkg
Pkg.add("ForwardDiff")
# Out:
#    Resolving package versions...
#      Project No packages added to or removed from `C:\Users\renye\.julia\environments\v1.12\Project.toml`
#     Manifest No packages added to or removed from `C:\Users\renye\.julia\environments\v1.12\Manifest.toml`

# %% [markdown]
# ## FONC example
#
# Plot the graphics of $f(x) = (x_1 - 3)^2 + (x_2 + 4)^2$

# %%
# code

# %% [markdown]
# ## Solving the FONC
#
# Given the function $z = (x_1 - 1)^4 + (x_2 - 2)^4$:
#
# * using the optim.jl package, find the minimum of z.
# * using the NLsolve.jl package, solve the FONC problem for this function

# %%
# code

# %% [markdown]
# Plot the level curve and the graphics of $f(x) = (x_1 - 3)^2 + (x_2 - 2)^2$

# %%
# code

# %% [markdown]
# Starting from the point $x = [1.0, 1.0]$, implement the gradient descent and Newton method to find the minimum of this function.

# %%
# code

# %% [markdown]
# Implement the same methods now for the function f(x) = 10(x_1 - 3)^2 + 2(x_2 - 2)^2$

# %%
# code

# %% [markdown]
# Now implement the same methods for the function $f(x) = x_1^2 + x_2^2$. Use as start point $x_0 = [-2.0, 2.0]$

# %%
# code

# %% [markdown]
# Implement the same methods for the function $f(x) = x_1^2 + 100x_2^2$. Use as start point $x_0 = [-2.0, 2.0]$

# %%
# code

# %% [markdown]
# For the last problem, perform the change of variables: $x_2 = \frac{1}{10}y_2$

# %% [markdown]
# ##  Gradient Descent with Backtracking Line Search:
#
# Given function:
# \begin{align*}
#     f(x_1, x_2, x_3) = x_{3} \log \Big( e^{\frac{x_{1}} {x_{3}}}+ e^{\frac{x_{2}} {x_{3}}} \Big) + (x_{3}-2)^2 + e^{\frac{1}{x_{1} + x_{2}}}
# \end{align*}
#
# $ \textbf{dom} \; f: \{ \mathbf{x} \in \mathbb{R}^3 : x_1 +x _2 >0, x_3 > 0 \}  $
#
# Define the function in the cell below:

# %%
# Função objetivo f(x₁, x₂, x₃)
function f(x)
    x1, x2, x3 = x[1], x[2], x[3]
    
    # Verificar se está no domínio
    if x1 + x2 <= 0 || x3 <= 0
        return Inf  # Fora do domínio -> retorna infinito
    end
    
    termo1 = x3 * log(exp(x1/x3) + exp(x2/x3))
    termo2 = (x3 - 2)^2
    termo3 = exp(1/(x1 + x2))
    
    return termo1 + termo2 + termo3
end
# Out:
# f (generic function with 1 method)

# %% [markdown]
# Defining the first derivative:
#
# $\nabla f = [ \partial f/\partial x_1 \; \partial f/\partial x_2 \; \partial f/\partial x_3]^T   $
#
# $$ \implies \nabla f = \begin{Bmatrix}
# \frac{e^{\frac{x_{1}} {x_{3}}}}{e^{\frac{x_{1}} {x_{3}}}+ e^{\frac{x_{2}} {x_{3}}}} - \frac{e^{ \frac{1}{x_1 + x_2}}}{(x_1 +x_2)^2}  \\ \\
# \frac{e^{\frac{x_{2}} {x_{3}}}}{e^{\frac{x_{1}} {x_{3}}}+ e^{\frac{x_{2}} {x_{3}}}} - \frac{e^{ \frac{1}{x_1 + x_2}}}{(x_1 +x_2)^2} \\ \\
#  log(e^{\frac{x_{1}} {x_{3}}}+ e^{\frac{x_{2}} {x_{3}}}) - \frac{x_1 e^{\frac{x_{1}} {x_{3}}} + x_2 e^{\frac{x_{2}} {x_{3}}}}{x_3 ( e^{\frac{x_{1}} {x_{3}}}+ e^{\frac{x_{2}} {x_{3}}}) } + 2(x_3-2)
# \end{Bmatrix}$$

# %% [markdown]
# #### implement the first derivative

# %%
# Gradiente da função f(x)
function grad_f(x)
    x1, x2, x3 = x[1], x[2], x[3]
    
    # Verificar domínio
    if x1 + x2 <= 0 || x3 <= 0
        return [NaN, NaN, NaN]
    end
    
    # Denominador comum para os termos com exponenciais
    den = exp(x1/x3) + exp(x2/x3)
    
    # Derivada parcial em relação a x1
    df_dx1 = (exp(x1/x3) / den) - exp(1/(x1 + x2)) / (x1 + x2)^2
    
    # Derivada parcial em relação a x2
    df_dx2 = (exp(x2/x3) / den) - exp(1/(x1 + x2)) / (x1 + x2)^2
    
    # Derivada parcial em relação a x3
    df_dx3 = log(den) - (x1*exp(x1/x3) + x2*exp(x2/x3)) / (x3 * den) + 2*(x3 - 2)
    
    return [df_dx1, df_dx2, df_dx3]
end
# Out:
# grad_f (generic function with 1 method)

# %% [markdown]
# Defining parameters for backtracking search: $\alpha = 0,4; \beta = 0,5;$ tolerance (eps) $= 10^{-5}$

# %%
# code

# %% [markdown]
# Start Point: [3.0, 4.0, 5.0]

# %%
# code

# %% [markdown]
# Ensuring domain:
#
# $ \text{While} \; x + t\Delta x \notin \textbf{dom} f, \text{ set } t := \beta t $ \
# where, $\Delta x = -\nabla f(x)$

# %%
# code

# %% [markdown]
# Backtracking algorithm:
#
# $
# \text{Given a descent direction } \Delta x = -\nabla f(x) \text{ for } f \text{ at } x \in \textbf{dom} f, \alpha \in (0, 0.5), \beta \in (0, 1).$
#
# \begin{array}{l}
# \text{Set } t := 1. \\
# \text{Ensure domain:} \; \text{While} \; x + t\Delta x \notin \textbf{dom} f, \text{ set } t := \beta t \\
# \text{While } f(x + t\Delta x) > f(x) + \alpha t \nabla f(x)^T \Delta x, \text{ set } t := \beta t.
# \end{array}

# %%
# code

# %% [markdown]
# ### Algorithm: Gradient Descent
#
# 1. **Input:** Starting point $x$ in $\text{dom} \, f$
#
# 2. **Repeat until stopping criterion is satisfied:**
#
#     a. $\Delta x := -\nabla f(x)$
#
#     b. **Line search:** Choose step size $t$ via backtracking line search
#
#     c. **Update:** $x := x + t \Delta x$

# %%
# Função de backtracking line search (CORRIGIDA)
function backtracking(f, grad_func, x, Δx, α, β)
    t = 1.0
    
    # Garantir domínio
    xt = x + t * Δx
    while xt[1] + xt[2] <= 0 || xt[3] <= 0
        t = β * t
        xt = x + t * Δx
    end
    
    g = grad_func(x)
    while f(x + t * Δx) > f(x) + α * t * dot(g, Δx)
        t = β * t
        # Verificar domínio novamente
        xt = x + t * Δx
        if xt[1] + xt[2] <= 0 || xt[3] <= 0
            continue
        end
    end
    
    return t
end

println("Função de backtracking definida!")
# Out:
# Função de backtracking definida!

# %%
# Gradient Descent com backtracking line search
function gradient_descent(f, grad, x0, α, β, ϵ, max_iter=1000)
    x = copy(x0)
    f_values = [f(x)]
    grad_norms = [norm(grad(x))]
    converged = false
    final_k = 0
    
    println("=== GRADIENT DESCENT ===")
    println("Iteração 0: x = $(round.(x, digits=6)), f(x) = $(round(f(x), digits=6))")
    
    for k in 1:max_iter
        g = grad(x)
        Δx = -g
        g_norm = norm(g)
        
        if g_norm ≤ ϵ
            converged = true
            final_k = k
            break
        end
        
        t = backtracking(f, grad, x, Δx, α, β)
        x = x + t * Δx
        
        push!(f_values, f(x))
        push!(grad_norms, g_norm)
        
        println("Iteração $k: x = $(round.(x, digits=6)), f(x) = $(round(f(x), digits=6)), ||grad|| = $(round(g_norm, digits=8))")
        final_k = k
    end
    
    if converged
        println("\n✅ Convergiu na iteração $final_k")
    else
        println("\n⚠️ Atingiu máximo de iterações ($max_iter)")
    end
    
    return x, f_values, grad_norms, final_k
end

# Executar
x_opt_gd, f_vals_gd, grad_norms_gd, iter_gd = gradient_descent(f, grad_f, [3.0, 4.0, 5.0], 0.4, 0.5, 1e-5)

println("\n=== RESULTADO FINAL ===")
println("x* = $(round.(x_opt_gd, digits=6))")
println("f(x*) = $(round(f(x_opt_gd), digits=6))")
println("Número de iterações: $iter_gd")
# Out:
# === GRADIENT DESCENT ===
# Iteração 0: x = [3.0, 4.0, 5.0], f(x) = 17.144259
# Iteração 1: x = [2.786688, 3.736854, 1.655914], f(x) = 5.760858, ||grad|| = 6.72239813
# Iteração 2: x = [2.453719, 3.124605, 1.690461], f(x) = 5.286118, ||grad|| = 0.69778994
# Iteração 3: x = [2.090099, 2.565116, 1.635699], f(x) = 4.850916, ||grad|| = 0.66951187
# Iteração 4: x = [1.719397, 2.050223, 1.681586], f(x) = 4.463701, ||grad|| = 0.636114
# Iteração 5: x = [1.360174, 1.592949, 1.630082], f(x) = 4.150456, ||grad|| = 0.58377485
# Iteração 6: x = [1.056692, 1.218189, 1.679314], f(x) = 3.958293, ||grad|| = 0.48473707
# Iteração 7: x = [0.880626, 0.994075, 1.628694], f(x) = 3.909881, ||grad|| = 0.28946241
# Iteração 8: x = [0.88186, 0.977902, 1.653729], f(x) = 3.908829, ||grad|| = 0.0596615
# Iteração 9: x = [0.891377, 0.958389, 1.653545], f(x) = 3.908456, ||grad|| = 0.02171109
# Iteração 10: x = [0.903329, 0.950081, 1.653513], f(x) = 3.908279, ||grad|| = 0.01455635
# Iteração 11: x = [0.909717, 0.942333, 1.653439], f(x) = 3.908194, ||grad|| = 0.01004228
# Iteração 12: x = [0.9149, 0.937653, 1.653462], f(x) = 3.908153, ||grad|| = 0.00698308
# Iteração 13: x = [0.918247, 0.934119, 1.653414], f(x) = 3.908133, ||grad|| = 0.00486714
# Iteração 14: x = [0.920681, 0.931754, 1.65345], f(x) = 3.908123, ||grad|| = 0.00339461
# Iteração 15: x = [0.922343, 0.930067, 1.653409], f(x) = 3.908118, ||grad|| = 0.00236808
# Iteração 16: x = [0.923516, 0.928904, 1.653447], f(x) = 3.908116, ||grad|| = 0.00165219
# Iteração 17: x = [0.924328, 0.928087, 1.653407], f(x) = 3.908115, ||grad|| = 0.0011529
# Iteração 18: x = [0.924898, 0.92752, 1.653446], f(x) = 3.908114, ||grad|| = 0.00080476
# Iteração 19: x = [0.925294, 0.927123, 1.653407], f(x) = 3.908114, ||grad|| = 0.00056211
# Iteração 20: x = [0.92557, 0.926847, 1.653446], f(x) = 3.908114, ||grad|| = 0.00039314
# Iteração 21: x = [0.925763, 0.926654, 1.653407], f(x) = 3.908114, ||grad|| = 0.0002757
# Iteração 22: x = [0.925898, 0.926519, 1.653446], f(x) = 3.908114, ||grad|| = 0.00019439
# Iteração 23: x = [0.925992, 0.926425, 1.653407], f(x) = 3.908114, ||grad|| = 0.00013851
# Iteração 24: x = [0.926057, 0.92636, 1.653446], f(x) = 3.908114, ||grad|| = 0.00010066
# Iteração 25: x = [0.926103, 0.926314, 1.653407], f(x) = 3.908114, ||grad|| = 7.568e-5
# Iteração 26: x = [0.926135, 0.926282, 1.653446], f(x) = 3.908114, ||grad|| = 5.987e-5
# Iteração 27: x = [0.926146, 0.926271, 1.653426], f(x) = 3.908114, ||grad|| = 5.041e-5
# Iteração 28: x = [0.926165, 0.926252, 1.653426], f(x) = 3.908114, ||grad|| = 2.669e-5
# Iteração 29: x = [0.926178, 0.926239, 1.653426], f(x) = 3.908114, ||grad|| = 1.862e-5
# Iteração 30: x = [0.926187, 0.92623, 1.653426], f(x) = 3.908114, ||grad|| = 1.299e-5
#
# ✅ Convergiu na iteração 31
#
# === RESULTADO FINAL ===
# x* = [0.926187, 0.92623, 1.653426]
# f(x*) = 3.908114
# Número de iterações: 31

# %% [markdown]
# ## Optimisation using Newton's Method:
#
# Given function:
# \begin{align*}
#     f(x_1, x_2, x_3) = x_{3} \log \Big( e^{\frac{x_{1}} {x_{3}}}+ e^{\frac{x_{2}} {x_{3}}} \Big) + (x_{3}-2)^2 + e^{\frac{1}{x_{1} + x_{2}}}
# \end{align*}
#
# $ \textbf{dom} \; f: \{ \mathbf{x} \in \mathbb{R}^3 : x_1 +x _2 >0, x_3 > 0 \}  $
#
# Defining the first derivative:
#
# $\nabla f = [ \partial f/\partial x_1 \; \partial f/\partial x_2 \; \partial f/\partial x_3]^T   $
#
# $$ \implies \nabla f = \begin{Bmatrix}
# \frac{e^{\frac{x_{1}} {x_{3}}}}{e^{\frac{x_{1}} {x_{3}}}+ e^{\frac{x_{2}} {x_{3}}}} - \frac{e^{ \frac{1}{x_1 + x_2}}}{(x_1 +x_2)^2}  \\ \\
# \frac{e^{\frac{x_{2}} {x_{3}}}}{e^{\frac{x_{1}} {x_{3}}}+ e^{\frac{x_{2}} {x_{3}}}} - \frac{e^{ \frac{1}{x_1 + x_2}}}{(x_1 +x_2)^2} \\ \\
#  log(e^{\frac{x_{1}} {x_{3}}}+ e^{\frac{x_{2}} {x_{3}}}) - \frac{x_1 e^{\frac{x_{1}} {x_{3}}} + x_2 e^{\frac{x_{2}} {x_{3}}}}{x_3 ( e^{\frac{x_{1}} {x_{3}}}+ e^{\frac{x_{2}} {x_{3}}}) } + 2(x_3-2)
# \end{Bmatrix}$$
#
# Defining the Second Derivative:
#
# The gradient vector, denoted as $\nabla f$, is the vector of partial derivatives:
# $
# \nabla f(x) = \left(\frac{\partial f}{\partial x_1}, \frac{\partial f}{\partial x_2}, \ldots, \frac{\partial f}{\partial x_n}\right)
# $
#
# The finite difference approximation for the gradient at a point $x$ is given by:
# $
# \nabla_f(x) \approx \frac{f(x + h\mathbf{i}) - f(x)}{h}
# $
# where $\mathbf{i}$ is a unit vector along one of the coordinate axes.
#
# The second derivative matrix is then approximated as:
# $
# \nabla^2 f(x) \approx \frac{1}{h} \left(\nabla_f(x + h\mathbf{i}) - \nabla_f(x)\right)
# $
#
# The reshaped second derivative matrix is a $3 \times 3$ matrix obtained from the flattened vector.

# %%
# code

# %%
# Parâmetros para backtracking line search
α = 0.4      # parâmetro de redução suficiente (Armijo)
β = 0.5      # fator de redução do passo
ϵ = 1e-5     # tolerância para critério de parada

# Ponto inicial
x0 = [3.0, 4.0, 5.0]

println("Parâmetros definidos:")
println("α = $α, β = $β, ϵ = $ϵ")
println("x0 = $x0")
# Out:
# Parâmetros definidos:
# α = 0.4, β = 0.5, ϵ = 1.0e-5
# x0 = [3.0, 4.0, 5.0]

# %%
# code

# %% [markdown]
# Ensuring domain:
#
# $ \text{While} \; x + t\Delta x \notin \textbf{dom} f, \text{ set } t := \beta t $ \
# where
# $\Delta x = -\nabla^2 f(x)^{-1} \nabla f(x)$

# %%
# Parâmetros para Newton's Method (mesmos do Gradient Descent)
α_newton = 0.4
β_newton = 0.5
ϵ_newton = 1e-5
x0_newton = [3.0, 4.0, 5.0]

println("Parâmetros para Newton's Method definidos!")
# Out:
# Parâmetros para Newton's Method definidos!

# %% [markdown]
# Backtracking algorithm:
#
# $
# \text{Given a descent direction } \Delta x = -\nabla^2 f(x)^{-1} \nabla f(x) \text{ for } f \text{ at } x \in \textbf{dom} f, \alpha \in (0, 0.5), \beta \in (0, 1).$
#
# \begin{array}{l}
# \text{Set } t := 1. \\
# \text{Ensure domain:} \; \text{While} \; x + t\Delta x \notin \textbf{dom} f, \text{ set } t := \beta t \\
# \text{While } f(x + t\Delta x) > f(x) + \alpha t \nabla f(x)^T \Delta x, \text{ set } t := \beta t.
# \end{array}

# %%
# code

# %% [markdown]
# # code

# %% [markdown]
# ### Newton's Algorithm
#
# **Input:** (defined earlier)
# - Starting point $x \in \text{dom} \, f$
# - Tolerance $\varepsilon > 0$
#
# **Repeat:**
# 1. Compute the Newton step and decrement.
#    $
#    \Delta x_{nt} := -\nabla^2 f(x)^{-1}\nabla f(x); \quad \lambda^2 := \nabla f(x)^T \nabla^2 f(x)^{-1}\nabla f(x)
#    $
# 2. Stopping criterion. $\textbf{quit}$ if $\lambda^2/2 \leq \varepsilon.$
# 3. Line search. Choose step size $t$ by backtracking line search; ensuring update $ := x + t \Delta x$ lies in $\mathbf{dom} f$ throughout.
# 4. Update. $x := x + t\Delta x_{nt}$.

# %%
# Hessiana usando diferenças finitas
function hess_f(x; h=1e-5)
    n = length(x)
    H = zeros(n, n)
    
    for i in 1:n
        ei = zeros(n)
        ei[i] = h
        H[:, i] = (grad_f(x + ei) - grad_f(x - ei)) / (2h)
    end
    
    return 0.5 * (H + H')  # garantir simetria
end

println("Função Hessiana definida!")
# Out:
# Função Hessiana definida!

# %%
# Newton's Method - VERSÃO FINAL CORRIGIDA
x_newton = [3.0, 4.0, 5.0]
α_val = 0.4
β_val = 0.5
ϵ_val = 1e-5
iter_newton = 0

println("=== NEWTON'S METHOD ===")
println("Iteração 0: x = $(round.(x_newton, digits=6)), f(x) = $(round(f(x_newton), digits=6))")

for k in 1:100
    g = grad_f(x_newton)
    g_norm = LinearAlgebra.norm(g)
    iter_newton = k
    
    if g_norm ≤ ϵ_val
        println("\n✅ Convergência atingida na iteração $(k)!")
        break
    end
    
    H = hess_f(x_newton)
    Δx = -H \ g
    t = backtracking(f, grad_f, x_newton, Δx, α_val, β_val)
    x_newton = x_newton + t * Δx
    
    println("Iteração $k: x = $(round.(x_newton, digits=6)), f(x) = $(round(f(x_newton), digits=6)), ||grad|| = $(round(g_norm, digits=8))")
end

println("\n=== RESULTADO FINAL ===")
println("x* = $(round.(x_newton, digits=6))")
println("f(x*) = $(round(f(x_newton), digits=6))")
println("Número de iterações: $iter_newton")
# Out:
# === NEWTON'S METHOD ===
# Iteração 0: x = [3.0, 4.0, 5.0], f(x) = 17.144259
# Iteração 1: x = [0.986376, 1.881595, 4.790683], f(x) = 13.980621, ||grad|| = 6.72239813
# Iteração 2: x = [0.777531, 0.929203, 3.220965], f(x) = 6.374252, ||grad|| = 6.2876163
# Iteração 3: x = [0.952786, 0.87891, 1.653288], f(x) = 3.908676, ||grad|| = 3.13919162
# Iteração 4: x = [0.92598, 0.926004, 1.653302], f(x) = 3.908114, ||grad|| = 0.0258996
# Iteração 5: x = [0.926208, 0.926208, 1.653426], f(x) = 3.908114, ||grad|| = 0.00048825
#
# ✅ Convergência atingida na iteração 6!
#
# === RESULTADO FINAL ===
# x* = [0.926208, 0.926208, 1.653426]
# f(x*) = 3.908114
# Número de iterações: 6

# %% [markdown]
# ## Optimisation using Quasi-Newton Method:
# ### The Broyden-Fletcher-Goldfarb-Shanno (BFGS) update

# %% [markdown]
# Given function:
# \begin{align*}
#     f(x_1, x_2, x_3) = x_{3} \log \Big( e^{\frac{x_{1}} {x_{3}}}+ e^{\frac{x_{2}} {x_{3}}} \Big) + (x_{3}-2)^2 + e^{\frac{1}{x_{1} + x_{2}}}
# \end{align*}
#
# $ \textbf{dom} \; f: \{ \mathbf{x} \in \mathbb{R}^3 : x_1 +x _2 >0, x_3 > 0 \}  $
#
# Defining the first derivative:
#
# $\nabla f = [ \partial f/\partial x_1 \; \partial f/\partial x_2 \; \partial f/\partial x_3]^T   $
#
# $$ \implies \nabla f = \begin{Bmatrix}
# \frac{e^{\frac{x_{1}} {x_{3}}}}{e^{\frac{x_{1}} {x_{3}}}+ e^{\frac{x_{2}} {x_{3}}}} - \frac{e^{ \frac{1}{x_1 + x_2}}}{(x_1 +x_2)^2}  \\ \\
# \frac{e^{\frac{x_{2}} {x_{3}}}}{e^{\frac{x_{1}} {x_{3}}}+ e^{\frac{x_{2}} {x_{3}}}} - \frac{e^{ \frac{1}{x_1 + x_2}}}{(x_1 +x_2)^2} \\ \\
#  log(e^{\frac{x_{1}} {x_{3}}}+ e^{\frac{x_{2}} {x_{3}}}) - \frac{x_1 e^{\frac{x_{1}} {x_{3}}} + x_2 e^{\frac{x_{2}} {x_{3}}}}{x_3 ( e^{\frac{x_{1}} {x_{3}}}+ e^{\frac{x_{2}} {x_{3}}}) } + 2(x_3-2)
# \end{Bmatrix}$$
#
# Defining the Second Derivative:
#
# The gradient vector, denoted as $\nabla f$, is the vector of partial derivatives:
# $
# \nabla f(x) = \left(\frac{\partial f}{\partial x_1}, \frac{\partial f}{\partial x_2}, \ldots, \frac{\partial f}{\partial x_n}\right)
# $
#
# The finite difference approximation for the gradient at a point $x$ is given by:
# $
# \nabla_f(x) \approx \frac{f(x + h\mathbf{i}) - f(x)}{h}
# $
# where $\mathbf{i}$ is a unit vector along one of the coordinate axes.
#
# The second derivative matrix is then approximated as:
# $
# \nabla^2 f(x) \approx \frac{1}{h} \left(\nabla_f(x + h\mathbf{i}) - \nabla_f(x)\right)
# $
#
# The reshaped second derivative matrix is a $3 \times 3$ matrix obtained from the flattened vector.

# %% [markdown]
# Defining parameters for backtracking search and the start point: $\alpha = 0,4; \beta = 0,5;$ tolerance (eps) $= 10^{-5}$; Start Point: [3.0, 4.0, 5.0]

# %%
# code

# %% [markdown]
# Ensuring domain:
#
# $ \text{While} \; x + t\Delta x \notin \textbf{dom} f, \text{ set } t := \beta t $
#
# Here, the direction $\Delta x$ has been taken as a parameter in the defined function and thus we need not explicitly calculate it again.

# %%
# code

# %%
# code

# %% [markdown]
# ### Running the BFGS Algorithm:
#
# **Given:**
# - Starting point $x_0$
# - Convergence tolerance $\epsilon > 0$ $(=10^{-5})$
# - Starting matrix $H_0$ (taken as Identity matrix)
#
# **Initialization:** $k \gets 0$
#
# **While:** $\| \nabla f_k \| > \epsilon$
# 1. Compute search direction by solving:
#    $ p_k = - H_k \nabla f_k $
# 2. Set $x_{k+1} = x_k + \alpha_k p_k$, where $\alpha_k$ is computed from backtracking line search procedure.
# 3. Define $s_k = x_{k+1} - x_k$ and $y_k = \nabla f_{k+1} - \nabla f_k$.
# 4. Compute $H_{k+1}$ using BFGS.
# 5. $k \gets k + 1$
#
# Finally, as mentioned in the implementation note to set $\rho_k $ as a constant after $y^T_k s_k$ gets smaller some certain $\epsilon$ say $10^{-5}$.\
# We have used an $\epsilon = 10^{-4}$ and set the value for  $\rho_k = 10^{4}$.

# %%
# BFGS - Quasi-Newton Method
function bfgs(f, grad, x0, α, β, ϵ, max_iter=100)
    n = length(x0)
    x = copy(x0)
    H = Matrix{Float64}(I, n, n)
    
    g = grad(x)
    g_norm = norm(g)
    f_values = [f(x)]
    grad_norms = [g_norm]
    converged = false
    final_k = 0
    
    println("=== BFGS (QUASI-NEWTON) ===")
    println("Iteração 0: x = $(round.(x, digits=6)), f(x) = $(round(f(x), digits=6))")
    
    for k in 1:max_iter
        if g_norm ≤ ϵ
            converged = true
            final_k = k - 1
            break
        end
        
        p = -H * g
        t = backtracking(f, grad, x, p, α, β)
        
        x_new = x + t * p
        g_new = grad(x_new)
        g_new_norm = norm(g_new)
        
        s = x_new - x
        y = g_new - g
        
        sy = dot(s, y)
        if sy > 1e-12
            ρ = 1.0 / sy
            H = (I - ρ * s * y') * H * (I - ρ * y * s') + ρ * s * s'
        end
        
        x = x_new
        g = g_new
        g_norm = g_new_norm
        
        push!(f_values, f(x))
        push!(grad_norms, g_norm)
        
        println("Iteração $k: x = $(round.(x, digits=6)), f(x) = $(round(f(x), digits=6)), ||grad|| = $(round(g_norm, digits=8))")
        final_k = k
    end
    
    if converged
        println("\n✅ Convergiu na iteração $final_k")
    end
    
    return x, f_values, grad_norms, final_k
end

# Executar
x_opt_bfgs, f_vals_bfgs, grad_norms_bfgs, iter_bfgs = bfgs(f, grad_f, [3.0, 4.0, 5.0], 0.4, 0.5, 1e-5)

println("\n=== RESULTADO FINAL ===")
println("x* = $(round.(x_opt_bfgs, digits=6))")
println("f(x*) = $(round(f(x_opt_bfgs), digits=6))")
println("Número de iterações: $iter_bfgs")
# Out:
# === BFGS (QUASI-NEWTON) ===
# Iteração 0: x = [3.0, 4.0, 5.0], f(x) = 17.144259
# Iteração 1: x = [2.786688, 3.736854, 1.655914], f(x) = 5.760858, ||grad|| = 0.69778994
# Iteração 2: x = [2.448465, 3.117079, 1.635356], f(x) = 5.280045, ||grad|| = 0.67025352
# Iteração 3: x = [1.325712, 1.339519, 1.607941], f(x) = 4.056166, ||grad|| = 0.42718864
# Iteração 4: x = [1.080947, 0.998151, 1.611004], f(x) = 3.925717, ||grad|| = 0.19804478
# Iteração 5: x = [0.981621, 0.884691, 1.631786], f(x) = 3.909367, ||grad|| = 0.05028818
# Iteração 6: x = [0.960471, 0.890095, 1.653935], f(x) = 3.90849, ||grad|| = 0.01516936
# Iteração 7: x = [0.947218, 0.904685, 1.657124], f(x) = 3.908264, ||grad|| = 0.01166419
# Iteração 8: x = [0.92701, 0.924489, 1.655182], f(x) = 3.908118, ||grad|| = 0.00366221
# Iteração 9: x = [0.926132, 0.926356, 1.653735], f(x) = 3.908114, ||grad|| = 0.00062248
# Iteração 10: x = [0.926165, 0.926221, 1.653427], f(x) = 3.908114, ||grad|| = 3.237e-5
# Iteração 11: x = [0.926211, 0.926211, 1.653426], f(x) = 3.908114, ||grad|| = 4.61e-6
#
# ✅ Convergiu na iteração 11
#
# === RESULTADO FINAL ===
# x* = [0.926211, 0.926211, 1.653426]
# f(x*) = 3.908114
# Número de iterações: 11

# %% [markdown]
# # Problem Statement: Optimal Control for CSTR
#
# We are given the liearized discrete state space model, time horizon, initial state, setpoints for controlled variables, and variable bounds

# %%
# IMPORTS

# %% [markdown]
# #### Defining state space model, time horizon, initial state, and variable bounds
#
# Note: since it is assumed that all the states are measurable without noise, here the controlled variables are represented using x instead for simplicity
#
# Hints: use matrix A, B from material. Time horizon = 3; Initial condition: [-0.03, 0.0, 0.3]; bounds: xmax = [0.05, 5, 0.5]; xmin = [-0.05, -5, -0.5]; umax = [10, 0.05]; umin = [-10, -0.05]

# %%
# linear state-space model

# code

# time horizon
# code

# initial condition
# code

# bounds for state and input
# code

# %% [markdown]
# ## Model
#
# The LP model for the problem can be derived as follows:
#
#
# \begin{aligned}
# \min_{u(0),u(1),u(2)} \quad &\sum_{k=0}^{k=3} (z_1(k)+z_2(k)) \\
# \textit{s.t.} \quad &{x}(k+1) ={A} {x}(k)+{B u}(k) \quad k=0,1,2 \\
# &y(k) ={C} {x}(k) \quad k=0,1,2,3 \\
# &{x}(0) = \begin{bmatrix}
# -0.03 \\
# 0 \\
# 0.3
# \end{bmatrix} \\
# &\begin{bmatrix}
# -0.05 \\
# -5 \\
# -0.5
# \end{bmatrix}
# \leq x(k) \leq
# \begin{bmatrix}
# 0.05 \\
# 5 \\
# 0.5
# \end{bmatrix} \quad k=0,1,2,3 \\
# &\begin{bmatrix}
# -10 \\
# -0.05
# \end{bmatrix}
# \leq u(k) \leq
# \begin{bmatrix}
# 10 \\
# 0.05
# \end{bmatrix} \quad k=0,1,2 \\
# &-z_1(k) \leq y_1(k) \leq z_1(k) \quad k=0,1,2,3 \\
# &-z_2(k) \leq y_3(k) \leq z_2(k) \quad k=0,1,2,3 \\
# \end{aligned}
#
#
#
# ## Implement

# %%
# code for optimization model

# %% [markdown]
# ## Solve and Postprocess

# %%
# code and plot some graphics

# plot controlled variables and input variables

# %%
using JuMP
using HiGHS

# %%
# Matrizes do sistema linearizado
A = [0.895 0.05 0.05;
     0.1  0.9  0.1;
     0.0  0.0  0.8]

B = [0.01 0.0;
     0.0  0.02;
     0.0  0.03]

# Matriz de saída (controlamos c e h)
C = [1 0 0;
     0 0 1]

# Horizonte de tempo
T = 3

# Estado inicial
x0 = [-0.03, 0.0, 0.3]

# Setpoints (queremos levar para zero)
csp = 0.0
hsp = 0.0

# Limites dos estados
xmin = [-0.05, -5.0, -0.5]
xmax = [0.05, 5.0, 0.5]

# Limites dos controles
umin = [-10.0, -0.05]
umax = [10.0, 0.05]

println("Dados do CSTR carregados!")
# Out:
# Dados do CSTR carregados!

# %%
# Modelo LP
model = Model(HiGHS.Optimizer)
set_silent(model)

# Variáveis de estado x(k) para k = 0,1,2,3
@variable(model, xmin[i] <= x[i=1:3, k=0:T] <= xmax[i])

# Variáveis de controle u(k) para k = 0,1,2
@variable(model, umin[i] <= u[i=1:2, k=0:T-1] <= umax[i])

# Variáveis auxiliares para valor absoluto
@variable(model, z1[0:T] >= 0)
@variable(model, z2[0:T] >= 0)

# Estado inicial
@constraint(model, x[:, 0] .== x0)

# Dinâmica do sistema
for k in 0:T-1
    @constraint(model, x[:, k+1] .== A * x[:, k] + B * u[:, k])
end

# Restrições de valor absoluto para y1 = c (x1)
for k in 0:T
    @constraint(model, -z1[k] <= x[1, k])
    @constraint(model, x[1, k] <= z1[k])
end

# Restrições de valor absoluto para y3 = h (x3)
for k in 0:T
    @constraint(model, -z2[k] <= x[3, k])
    @constraint(model, x[3, k] <= z2[k])
end

# Função objetivo: minimizar soma dos desvios absolutos
@objective(model, Min, sum(z1[k] + z2[k] for k in 0:T))

# Resolver
optimize!(model)

println("Status: ", termination_status(model))
println("Valor ótimo: ", round(objective_value(model), digits=6))
# Out:
# Status: OPTIMAL
# Valor ótimo: 0.90774

# %%
# Extrair resultados
X_opt = value.(x)
U_opt = value.(u)

println("\n=== ESTADOS ÓTIMOS ===")
for k in 0:T
    println("k=$k: x = [$(round(X_opt[1,k], digits=4)), $(round(X_opt[2,k], digits=4)), $(round(X_opt[3,k], digits=4))]")
end

println("\n=== CONTROLES ÓTIMOS ===")
for k in 0:T-1
    println("k=$k: u = [$(round(U_opt[1,k], digits=4)), $(round(U_opt[2,k], digits=4))]")
end

println("\n=== VERIFICAÇÃO ===")
println("x(0) = [$(round(X_opt[1,0], digits=4)), $(round(X_opt[2,0], digits=4)), $(round(X_opt[3,0], digits=4))]")
println("x($T) = [$(round(X_opt[1,T], digits=4)), $(round(X_opt[2,T], digits=4)), $(round(X_opt[3,T], digits=4))]")
# Out:
# === ESTADOS ÓTIMOS ===
# k=0: x = [-0.03, -0.0, 0.3]
# k=1: x = [-0.0, 0.026, 0.2385]
# k=2: x = [-0.0, 0.0462, 0.1893]
# k=3: x = [-0.0, 0.0596, 0.1499]
#
# === CONTROLES ÓTIMOS ===
# k=0: u = [1.185, -0.05]
# k=1: u = [-1.3225, -0.05]
# k=2: u = [-1.1778, -0.05]
#
# === VERIFICAÇÃO ===
# x(0) = [-0.03, -0.0, 0.3]
# x(3) = [-0.0, 0.0596, 0.1499]
